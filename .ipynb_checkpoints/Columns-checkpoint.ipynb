# %%
#MAIN COLUMNS
#Define columns and an alias to show in the plots
def main_columns(data):
    labels = { 
        #Column : Alias
        'Measurement': "Measurement",
        'Time': "Time",
        'Date': "Date",
        'Date_Time':'Date_Time',
        'Test_time':'Test time',    
    }
    labels = {i:v for i,v in labels.items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels

# %%
#TEMPERATURE 
#Define columns and an alias to show in the plots
def temp_columns(data, project):
    labels = { 
        "STEP1":{
            #Column : Alias
            'PFC_Temp_M1_C': "CAN: Temp NTC 1 (cooler)",
            'PFC_Temp_M4_C': "CAN: Temp NTC 4 (cooler)",
            'DCDC_Temperature': "CAN: DCDC Temp",
            'Chiller_T_Actl': "Chiller: Coolant Temp",
            'OBC_Temp_Ambient': "CAN: OBC_Temp_Ambient",
            'DCHV_ADC_NTC_MOD_5': "CAN: DCHV_ADC_NTC_MOD_5",
            'DCHV_ADC_NTC_MOD_6': "CAN: DCHV_ADC_NTC_MOD_6",
            'OBC_OBCTemp': "CAN: OBC_OBCTemp",
            'DCLV_T_SW_BUCK_A': "CAN: DCLV_T_SW_BUCK_A",
            'DCLV_T_SW_BUCK_A': "CAN: DCLV_T_SW_BUCK_B",
            'DCLV_T_PP_A': "CAN: DCLV_T_PP_A",
            'DCLV_T_PP_B': "CAN: DCLV_T_PP_B",
            'DCDC_Temperature': "CAN: DCDC_Temperature"
        },
        "BEV":{
            #Column : Alias
            'PFC_Temp_PFC': 'PFC_Temp_PFC',
            'PFC_Temp_DCHV': 'PFC_Temp_DCHV',
            'DCHV_T_PCB_Measure': 'DCHV_T_PCB_Measure',
            'DCHV_T_REC_Measure': 'DCHV_T_REC_Measure',
            'DCLV_T_INV_Measure': 'DCLV_T_INV_Measure',
            'DCLV_T_SR_Measure': 'DCLV_T_SR_Measure',    
            'C_chamber_T_actl': 'C_chamber_T_actl',
            'Chiller_T_Actl': 'Chiller_T_Actl'
        },
        "PHEV":{
            #Column : Alias
            'PFC_Temp_PFC': 'PFC_Temp_PFC',
            'PFC_Temp_DCHV': 'PFC_Temp_DCHV',
            'DCHV_T_PCB_Measure': 'DCHV_T_PCB_Measure',
            'DCHV_T_REC_Measure': 'DCHV_T_REC_Measure',
            'DCLV_T_INV_Measure': 'DCLV_T_INV_Measure',
            'DCLV_T_SR_Measure': 'DCLV_T_SR_Measure',    
            'C_chamber_T_actl': 'C_chamber_T_actl',
            'Chiller_T_Actl': 'Chiller_T_Actl'
        }        

    }
    labels = {i:v for i,v in labels[project].items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels

# %%
#MEASUREMENTS FROM HV AC I/O
#Define columns and an alias to show in the plots
#Voltage
def hvac_v_columns(data, project):
    labels = {
        "STEP1":{
            #Column : Alias
            'PFC_VPH12_RMS_V': "CAN: Phase 1 Input Voltage",
            'PFC_VPH23_RMS_V': "CAN: Phase 2 Input Voltage",
            'PFC_VPH31_RMS_V': "CAN: Phase 3 Input Voltage",  
            'PFC_Vdclink_V': "CAN: DC Link Voltage",    
            'SUP_CommandVDCLink_V': 'CAN: PFC DC Link command',
        },
        "BEV":{
            #Column : Alias
            'PFC_VPH12_RMS': 'PFC_VPH12_RMS',
            'PFC_Vdclink_V': 'PFC_Vdclink_V',    
            'SUP_CommandVDCLink_V': 'SUP_CommandVDCLink_V',
        },
        "PHEV":{
            #Column : Alias
            'PFC_VPH12_RMS': 'PFC_VPH12_RMS',
            'PFC_Vdclink_V': 'PFC_Vdclink_V',    
            'SUP_CommandVDCLink_V': 'SUP_CommandVDCLink_V',
        },    
    }
    labels = {i:v for i,v in labels[project].items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels

#Current
def hvac_i_columns(data, project):
    labels = {
        "STEP1": {
            #Column : Alias
            'PFC_IPH1_RMS_0A1': "CAN: Phase 1 Input Current",
            'PFC_IPH2_RMS_0A1': "CAN: Phase 2 Input Current",
            'PFC_IPH3_RMS_0A1': "CAN: Phase 3 Input Current",    
        },
        "BEV":{
            #Column : Alias
            'PFC_IPH1_RMS': 'PFC_IPH1_RMS',
        },
        "PHEV":{
            #Column : Alias
            'PFC_IPH1_RMS': 'PFC_IPH1_RMS',
        },        
    }
    labels = {i:v for i,v in labels[project].items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels

#Power
def hvac_p_columns(data, project):
    labels = {
        "STEP1":{
            #Column : Alias 
            'OBC_PowerMax': "CAN: Max P (derating)",
        },
        "BEV":{
            #Column : Alias         
            'OBC_PowerMax': 'Max P (derating)',
        },
        "PHEV":{
            #Column : Alias         
            'OBC_PowerMax': 'Max P (derating)',
        }    
    }
    labels = {i:v for i,v in labels[project].items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels

# %%
#MEASUREMENTS FROM HV DC I/O
#Define columns and an alias to show in the plots
def hvdc_v_columns(data, project):
    labels = {
        "STEP1":{
            #Column : Alias    
            'DCHV_ADC_VOUT': "CAN: HV DCDC Output Voltage",
            'DCHV_Command_Voltage_Reference': "CAN: DCHV_Command_Voltage_Reference",            
        },
        "BEV":{
            #Column : Alias    
            'DCHV_BAT_V_Measure': 'DCHV_BAT_V_Measure',
            'HVDC_load_V': 'HVDC_load_V',  
        },
        "PHEV":{
            #Column : Alias    
            'DCHV_BAT_V_Measure': 'DCHV_BAT_V_Measure',
            'HVDC_load_V': 'HVDC_load_V',  
        }    
    }
    labels = {i:v for i,v in labels[project].items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels 

def hvdc_i_columns(data, project):
    labels = {
        "STEP1":{
            #Column : Alias    
            'DCHV_ADC_IOUT': "CAN: HV DCDC Output current",
            'DCHV_Command_Current_Reference': "CAN: DCHV_Command_Current_Reference",                        
        },
        "BEV":{
            #Column : Alias    
            'DCHV_BAT_I_Measure': 'DCHV_BAT_I_Measure',
            'HVDC_load_I': 'HVDC_load_I',  
        },
        "PHEV":{
            #Column : Alias    
            'DCHV_BAT_I_Measure': 'DCHV_BAT_I_Measure',
            'HVDC_load_I': 'HVDC_load_I',    
        } 
    }
    labels = {i:v for i,v in labels[project].items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels

def hvdc_p_columns(data, project):
    labels = {
        #Column : Alias
        "STEP1":{
            #Column : Alias    
        },
        "BEV":{
            #Column : Alias    
            'HVDC_load_P': 'HVDC_load_P',
        },
        "PHEV":{
            #Column : Alias    
            'HVDC_load_P': 'HVDC_load_P',
        } 
    }
    labels = {i:v for i,v in labels[project].items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels

# %%
#MEASUREMENTS FROM LV DC I/O
#Define columns and an alias to show in the plots
def lvdc_v_columns(data, project):
    labels = {
        "STEP1":{
            #Column : Alias        
            'DCLV_Measured_Voltage': "CAN: LV DCDC output Voltage",
            'DCLV_VoltageReference': "CAN: DCLV_VoltageReference",            
        },
        "BEV":{
            #Column : Alias        
            'DCLV_LV_V_Measure': 'DCLV_LV_V_Measure',
            'LVDC_load_V': 'LVDC_load_V',   
        },
        "PHEV":{
            #Column : Alias        
            'DCLV_LV_V_Measure': 'DCLV_LV_V_Measure',
            'LVDC_load_V': 'LVDC_load_V', 
        },    
    }
    labels = {i:v for i,v in labels[project].items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels   
def lvdc_i_columns(data, project):
    labels = {
        "STEP1":{
            #Column : Alias        
            'DCLV_Measured_Current': "CAN: LV DCDC output Current",
            'DCLV_Command_Current_Reference': "CAN: DCLV_Command_Current_Reference",            
        },
        "BEV":{
            #Column : Alias        
            'DCLV_LV_I_Measure': 'DCLV_LV_I_Measure',
            'LVDC_load_I': 'LVDC_load_I',  
        },
        "PHEV":{
            #Column : Alias        
            'DCLV_LV_I_Measure': 'DCLV_LV_I_Measure',
            'LVDC_load_I': 'LVDC_load_I',
        },       
    }
    labels = {i:v for i,v in labels[project].items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels   
def lvdc_p_columns(data, project):
    labels = {
        #Column : Alias        
        "STEP1":{
            #Column : Alias        
            'DCLV_Power': 'CAN: DCLV_Power',
            'DCLV_Applied_Derating_Factor': 'CAN: DCLV_Applied_Derating_Factor',            
        },
        "BEV":{
            #Column : Alias        
            'LVDC_load_P': 'LVDC_load_P',
        },
        "PHEV":{
            #Column : Alias        
            'LVDC_load_P': 'LVDC_load_P',
        },   
    }
    labels = {i:v for i,v in labels[project].items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels

# %%
#STATUS
#Define columns and an alias to show in the plots
def status_columns(data, project):
    labels = {
        #Column : Alias        
        "STEP1":{
            #Column : Alias        
            'PFC_PFCStatus': "CAN: PFC Status",
            'DCHV_DCHVStatus': "CAN: HV DC Status",
            'OBC_Status': "CAN: OBC Status",
            'OBC_Fault': "CAN: OBC Fault",
            #'Actual_Cycle': "Actual Cycle",
        },
        "BEV":{
            #Column : Alias        
            'PFC_PFCStatus': 'PFC_PFCStatus',
            'DCHV_DCHVStatus': 'DCHV_DCHVStatus',
            'DCLV_DCLVStatus': 'DCLV_DCLVStatus',
            'OBC_Fault': 'OBC_Fault',
            'Actual_Cycle': 'Actual_Cycle',
            'SUP_DEBUG_Derating_DCDC':'SUP_DEBUG_Derating_DCDC',
            'SUP_DEBUG_Derating_OBC':'SUP_DEBUG_Derating_OBC'  
        },
        "PHEV":{
            #Column : Alias        
            'PFC_PFCStatus': 'PFC_PFCStatus',
            'DCHV_DCHVStatus': 'DCHV_DCHVStatus',
            'DCLV_DCLVStatus': 'DCLV_DCLVStatus',
            'OBC_Fault': 'OBC_Fault',
            'Actual_Cycle': 'Actual_Cycle',
            'SUP_DEBUG_Derating_DCDC':'SUP_DEBUG_Derating_DCDC',
            'SUP_DEBUG_Derating_OBC':'SUP_DEBUG_Derating_OBC'  
        },      
    }
    labels = {i:v for i,v in labels[project].items() if i in data.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels

# %%
#DATA LOGGER
#Define columns and an alias to show in the plots
def dl1_columns(data):
    labels = {
        #Column : Alias        
        #To fill up
    }
    labels = {i:v for i,v in labels.items() if i in df.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels

def dl2_columns(data):
    labels = {
        #Column : Alias        
        #To fill up
    }
    labels = {i:v for i,v in labels.items() if i in df.columns} #Remove items from the list if a column with that name does not exist in the dataframe
    return labels
